# %% [markdown]
# # Notebook 05: Conclusiones
# ## Proyecto Integrador — Minería de Datos I
#
# **Objetivo:** Responder a los objetivos y preguntas definidos por el grupo, diferenciando evidencia, interpretación y conclusión. Incluir limitaciones del análisis y propuestas de mejoras futuras.

# %%
import pandas as pd
import numpy as np

# Cargar dataset procesado para tener los datos a mano
df = pd.read_csv('../data/processed/reporte_clinica_analisis.csv')

# Datos clave para referenciar en conclusiones
smoker_means = df.groupby('smoker')['charges'].mean()
age_corr = df['age'].corr(df['charges'])
bmi_corr = df['bmi'].corr(df['charges'])
children_corr = df['children'].corr(df['charges'])

print('Datos de referencia para conclusiones:')
print(f'  Ratio fumador/no fumador: {smoker_means["yes"]/smoker_means["no"]:.2f}x')
print(f'  Corr age-charges: {age_corr:.3f}')
print(f'  Corr bmi-charges: {bmi_corr:.3f}')
print(f'  Corr children-charges: {children_corr:.3f}')
print(f'  N total: {len(df)}')

# %% [markdown]
# ---
#
# ## 1. Respuesta a los objetivos del proyecto
#
# ### Objetivo general
#
# > Analizar los factores que influyen en el costo del seguro médico utilizando técnicas de análisis exploratorio, reducción de dimensionalidad y visualización interactiva, para identificar los principales determinantes del costo y comunicar los hallazgos de manera efectiva.
#
# ### Preguntas de análisis y respuestas

# %% [markdown]
# ### P1: ¿Cómo se distribuyen los costos del seguro médico?
#
# | | Evidencia | Interpretación | Conclusión |
# |---|---|---|---|
# | **Dato** | Media: $13,256 | Mediana: $9,361 | Asimetría: 1.51 | La distribución de costos está fuertemente sesgada hacia la derecha | La mayoría de los asegurados paga entre $2,000 y $15,000, pero un grupo reducido (principalmente fumadores) genera costos muy elevados | **El costo del seguro no se distribuye uniformemente:** un subconjunto pequeño de la población concentra costos desproporcionadamente altos |
#
# **Fuente:** Notebook 03, Sección 1.1 (Histograma y boxplot de charges).

# %% [markdown]
# ### P2: ¿El tabaquismo influye en el costo del seguro?
#
# | | Evidencia | Interpretación | Conclusión |
# |---|---|---|---|
# | **Dato** | Fumadores pagan en promedio **3.2× más** que no fumadores (corr = 0.79 con charges) | La diferencia es estadística y prácticamente significativa. Existe una separación clara entre las distribuciones de costos de ambos grupos | El tabaquismo no solo aumenta el costo: los fumadores muestran además mayor dispersión, lo que indica que dentro de este grupo hay subgrupos de riesgo aún más elevado | **El tabaquismo es el factor individual con mayor impacto en el costo del seguro médico** |
#
# **Fuente:** Notebook 03, Sección 2.1 (Boxplot y violin plot).

# %% [markdown]
# ### P3: ¿Cómo se relaciona la edad con el costo?
#
# | | Evidencia | Interpretación | Conclusión |
# |---|---|---|---|
# | **Dato** | Correlación edad-costo: r = 0.305. La pendiente de costo por año es mayor en fumadores que en no fumadores | Existe una relación positiva moderada, pero el efecto de la edad se amplifica en fumadores | La edad por sí sola no es un predictor fuerte: es la **interacción edad + tabaquismo** lo que dispara los costos | **La edad es un factor relevante, pero su impacto está mediado por la condición de fumador** |
#
# **Fuente:** Notebook 03, Sección 2.2 (Scatter plot con tendencias).

# %% [markdown]
# ### P4: ¿Hay diferencias regionales en los costos?
#
# | | Evidencia | Interpretación | Conclusión |
# |---|---|---|---|
# | **Dato** | Correlaciones región-costo ≤ 0.05 en valor absoluto | Las diferencias regionales en el costo del seguro son insignificantes desde el punto de vista estadístico | La región geográfica no es un factor determinante del costo. Las diferencias observadas pueden atribuirse a variabilidad muestral | **No se encontró evidencia de que la región influya significativamente en el costo del seguro** |
#
# **Fuente:** Notebook 03, Sección 3.1 (Matriz de correlación).

# %% [markdown]
# ### P5: ¿Qué combinación de factores explica mejor la variabilidad en los costos?
#
# | | Evidencia | Interpretación | Conclusión |
# |---|---|---|---|
# | **Dato** | PCA: PC1 (dominada por smoker, charges, age) captura la mayor varianza. Las demás variables contribuyen poco | La variabilidad en los costos puede reducirse a un número menor de dimensiones: la primera componente principal concentra la información relevante sobre riesgo y costo | El PCA confirma el EDA: las variables clave son tabaquismo y edad. Las demás (bmi, children, sex, region) añaden poca información adicional | **La estructura de los datos está dominada por un eje de costo/riesgo definido por tabaquismo y edad** |
#
# **Fuente:** Notebook 04 (PCA).

# %% [markdown]
# ---
#
# ## 2. Conclusión general
#
# El análisis realizado sobre el dataset de costos de seguro médico (1,363 asegurados, 7 variables) permite concluir que:
#
# 1. **El tabaquismo es el factor dominante.** Los fumadores pagan en promedio más del triple que los no fumadores, y esta variable por sí sola explica la mayor parte de la variabilidad en los costos (corr = 0.79).
#
# 2. **La edad es un factor secundario pero relevante,** especialmente cuando interactúa con el tabaquismo: los fumadores de mayor edad son el grupo de mayor costo.
#
# 3. **El IMC (bmi) tiene un efecto menor** en comparación con tabaquismo y edad, aunque positivo.
#
# 4. **El sexo, la región y el número de hijos no son factores determinantes** del costo del seguro en este dataset.
#
# 5. **El PCA confirma que los datos pueden representarse eficientemente en menos dimensiones,** con la primera componente principal capturando el eje de costo/riesgo definido por tabaquismo y edad.

# %% [markdown]
# ---
#
# ## 3. Limitaciones
#
# Las siguientes limitaciones condicionan el alcance de las conclusiones presentadas:
#
# 1. **Calidad de los datos originales:** El dataset contenía 152 valores nulos (11.2% de las celdas en age y bmi) y múltiples inconsistencias en variables categóricas. Si bien se aplicaron técnicas de imputación y estandarización, estas decisiones introducen un grado de incertidumbre en los resultados.
#
# 2. **Alcance de las variables disponibles:** El dataset incluye solo 7 variables. Factores potencialmente relevantes como condiciones médicas preexistentes, historial familiar, hábitos de ejercicio o nivel socioeconómico no están disponibles, lo cual limita la capacidad explicativa del modelo.
#
# 3. **Naturaleza observacional de los datos:** El análisis es descriptivo y correlacional. No se pueden establecer relaciones causales entre las variables y el costo del seguro. Las correlaciones observadas no implican causalidad.
#
# 4. **Representatividad de la muestra:** No se dispone de información sobre cómo se recolectaron los datos ni sobre su representatividad respecto a la población general. Los resultados deben interpretarse dentro del alcance de este dataset específico.
#
# 5. **Imputación de valores:** La decisión de imputar valores nulos con la mediana, aunque robusta, puede haber suavizado la variabilidad real de las variables afectadas (age: 102 imputaciones, bmi: 70 imputaciones).

# %% [markdown]
# ---
#
# ## 4. Mejoras futuras
#
# Las siguientes acciones podrían ampliar, fortalecer o profundizar el proyecto en una etapa posterior:
#
# 1. **Incorporar variables adicionales:** Incluir información sobre condiciones médicas preexistentes, nivel de actividad física, historial familiar de enfermedades y nivel socioeconómico permitiría construir un modelo más completo de los determinantes del costo.
#
# 2. **Aplicar técnicas de imputación más avanzadas:** Utilizar imputación múltiple (MICE) o modelos predictivos (KNN, regresión) en lugar de la mediana podría producir estimaciones más precisas de los valores faltantes.
#
# 3. **Modelado predictivo:** Extender el análisis más allá de la exploración y el PCA hacia modelos supervisados (regresión lineal múltiple, random forest, gradient boosting) para cuantificar la importancia relativa de cada factor y predecir costos.
#
# 4. **Análisis de interacciones:** Investigar formalmente las interacciones entre variables (edad × tabaquismo, bmi × tabaquismo) mediante modelos con términos de interacción.
#
# 5. **Segmentación de asegurados:** Aplicar clustering (K-means, DBSCAN) sobre las componentes principales para identificar perfiles de asegurados y diseñar estrategias diferenciadas de gestión de riesgo.
#
# 6. **Validación externa:** Contrastar los hallazgos con datasets similares de otras fuentes para evaluar la generalizabilidad de las conclusiones.

# %% [markdown]
# ---
#
# ## 5. Coherencia con otros entregables
#
# Las conclusiones presentadas aquí son coherentes con:
#
# - **Informe final (reports/informe_final.pdf):** Resume los mismos hallazgos en formato PDF de máximo 2 páginas.
# - **Aplicación Streamlit (app/):** Comunica los resultados al público general mediante visualizaciones interactivas.
# - **README.md:** Documenta técnicamente el proyecto con enlaces a notebooks, informe y aplicación.
#
# Cada entregable presenta la misma evidencia desde una perspectiva diferente, sin duplicar contenido.
